# %% [markdown]
# Importing libs

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4,5]
y = [4,4,9,16,25]

plt.plot(x, y)
plt.grid()

plt.title('My First Graph!')
plt.xlabel('X-label')
plt.ylabel('Y-label')

plt.show()
